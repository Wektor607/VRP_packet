# %%
# lst = [
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201025_141430.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201025_142105.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201101_150113.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201115_132354.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201116_232344.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201224_222701.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201225_204810.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201228_230627.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20200925_093755.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20200927_100114.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20200928_114457.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20200930_163005.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201005_160200.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201008_165020.csv", 
#         "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/20(20_задач)/20201014_154416.csv" 
# ]

# lst_distance = [
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201025_141430_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201025_142105_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201101_150113_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201115_132354_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201116_232344_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201224_222701_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201225_204810_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201228_230627_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20200925_093755_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20200927_100114_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20200928_114457_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20200930_163005_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201005_160200_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201008_165020_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/20(20 задач)/20201014_154416_dist.csv"
# ]

# %%
# lst = [ 
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201203_215226.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201204_205445.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201209_152236.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201214_185310.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201007_185322.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201023_203450.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201026_211708.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201027_214904.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201028_202211.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201029_201947.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201105_201910.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201109_190333.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201110_211510.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201110_212146.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201117_214239.csv", #
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201127_184250.csv",#
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/LKH/LKH_C/50(20 задач)/20201128_220622.csv" #
#     ]

# lst_distance = [ 
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201203_215226_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201204_205445_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201209_152236_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201214_185310_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201007_185322_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201023_203450_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201026_211708_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201027_214904_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201028_202211_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201029_201947_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201105_201910_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201109_190333_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201110_211510_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201110_212146_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201117_214239_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201127_184250_dist.csv",
#     "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/50(20_задач)/20201128_220622_dist.csv"
#     ]

# %%
lst = [
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201020_182616.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201021_185504.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201111_223641.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201118_223519.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201119_230826.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201123_210620.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201125_032739.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201125_225552.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201126_190637.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201130_210949.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201201_165823.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201202_191224.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201208_202137.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201215_221946.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201216_183747.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201217_144624.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201224_012524.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20210105_235706.csv"
]

lst_distance = [
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201020_182616_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201021_185504_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201111_223641_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201118_223519_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201119_230826_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201123_210620_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201125_032739_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201125_225552_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201126_190637_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201130_210949_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201201_165823_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201202_191224_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201208_202137_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201215_221946_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201216_183747_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201217_144624_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20201224_012524_dist.csv",
    "C:/Users/German/Desktop/Курсовая_работа/Алгоритмы/Датасеты/100(20_задач)/20210105_235706_dist.csv"
]

# %%
# %%time
from gurobipy import *
from gurobipy import Model, GRB, quicksum
import pandas as pd
import random
from geopy.distance import geodesic
import threading
from random import randint
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
import operator
import itertools
import os.path
import time
import copy

# %%
# %%time
for name_file1, name_file2 in zip(lst, lst_distance):
    # Запишем все данные в виде массива списков
    data_file  = pd.read_csv(name_file1, sep="\t", error_bad_lines=True)
    arr_data   = data_file.values
    
    # Задаём объем грузовика
    Q = 50 # Для 20:30, 50:40, 100:50
    
    # Создаём списки координат и грузов для каждого клиента
    xc       = np.zeros(len(arr_data))
    yc       = np.zeros(len(arr_data))
    capacity = np.zeros(len(arr_data))
    w = 0
    for j in range(len(arr_data)):
        if(arr_data[j][2] <= Q):
            xc[w]       = arr_data[j][0]
            yc[w]       = arr_data[j][1]
            capacity[w] = arr_data[j][2]
            w += 1
    # Отдельно записываем координаты депо и исключаем их из списка координта и capacity клиентов       
    depo_xc  = xc[w-1]
    depo_yc  = yc[w-1]
    xc       = xc[:w-1]
    yc       = yc[:w-1]
    capacity = capacity[:w-1]
    
    # Исключаем депо из списка клиентов
    w -= 1
    
    #Создаем список клиентов
    clients = []   
    for i in range(0, w):
        clients.append(i)
    
    # Cоздаем список клиентов вместе с депо
    V = [len(arr_data) - 1] + clients

    A = [(i,j) for i in V for j in V if i != j] # possible arcs
    
    c = {}
    sheet_dist  = pd.read_csv(name_file2, sep=",", error_bad_lines=False)
    for i,j in A:
        print((i,j))
        if(i == len(arr_data) - 1 and j <= max(A)[1]):
            for k in range(len(sheet_dist)):
                if(depo_xc == sheet_dist.values[k][0] and depo_yc == sheet_dist.values[k][1] and xc[j] == sheet_dist.values[k][2] and yc[j] == sheet_dist.values[k][3]):
                    c[(i,j)] = sheet_dist.values[k][4]
                    break
        elif(i <= max(A)[1] and j == len(arr_data) - 1):
            for k in range(len(sheet_dist)):
                if(xc[i] == sheet_dist.values[k][0] and yc[i] == sheet_dist.values[k][1] and depo_xc == sheet_dist.values[k][2] and depo_yc == sheet_dist.values[k][3]):
                    c[(i,j)] = sheet_dist.values[k][4]
                    break
        else:
            for k in range(len(sheet_dist)):
                if(xc[i] == sheet_dist.values[k][0] and yc[i] == sheet_dist.values[k][1] and xc[j] == sheet_dist.values[k][2] and yc[j] == sheet_dist.values[k][3]):
                    c[(i,j)] = sheet_dist.values[k][4]
                    break
                    
    q = {i: capacity[i] for i in clients} # number of VRUs at location i to be picked
    q[len(arr_data) - 1] = 0
    time_limit = 200
    lst = []
    lst_time = []
    #-----------------------------------------------------------------------------------------------------------------#        
    model = Model('CVRP')

    # Declaration of variables
    x = model.addVars(A, vtype= GRB.BINARY)
    y = model.addVars(clients, vtype= GRB.CONTINUOUS)
    # setting the objective function
    model.modelSense = GRB.MINIMIZE
    model.setObjective(quicksum(x[i, j]*c[i, j] for i, j in A))
    # Adding constraints
    model.addConstrs(quicksum(x[i,j] for j in V if j!=i) == 1 for i in clients)
    model.addConstrs(quicksum(x[i,j] for i in V if i!=j) == 1 for j in clients)
    model.addConstrs((x[i,j] == 1) >> (y[i] + q[j] == y[j]) for (i,j) in A if i != len(arr_data) - 1 and j != len(arr_data) - 1)
    model.addConstrs(y[i] >= q[i] for i in clients)
    model.addConstrs(y[k] <= Q for k in clients)

    # Optimizing the model
    model.Params.TimeLimit = time_limit  # seconds
    model.Params.LogFile= "result_Branch_and_Cut_100.txt"
    model.optimize()
    if model.status == GRB.OPTIMAL:
        print('1.Optimal objective: %g' % model.objVal)
        print('Optimal cost: %g' % model.objVal)
        lst.append(model.objVal)
        lst_time.append(model.Runtime)
    elif model.status == GRB.INF_OR_UNBD:
        print('2.Model is infeasible or unbounded')
        res = -1
    elif model.status == GRB.INFEASIBLE:
        print('3.Model is infeasible')
        res = -1
    elif model.status == GRB.UNBOUNDED:
        print('4.Model is unbounded')
        res = -1
    else:
        print('5.Optimization ended with status %d' % model.status)
        print('Optimal cost: %g' % model.objVal)
        lst.append(model.objVal)
        lst_time.append(time_limit)

# %%
infile = open('result_Branch_and_Cut_100.txt',  'r')
outfile = open('result_Gurobi_100.txt',  'w')

copy = False
for line in infile:
    if 'Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time' in line:
        copy = True
    elif 'Cutting planes:' in line:
        copy = False
        
    elif copy:
        content = line.split()
        new_line = ''
        if len(content) == 10:
            new_line += content[5]
        elif len(content) == 8:
            new_line += content[3]
        
        if len(content) != 0:
#             content = content[:-1]
            new_line += '\t' + content[-1] 
            new_line = new_line[:-1] + '\n'
            if(new_line[0] != '\t'):
                outfile.write(new_line)
infile.close()
outfile.close()

# %%
infile = open('result_Gurobi_100.txt',  'r')
outfile = open('res_Gurobi_100.txt',  'w')

with open('result_Gurobi_100.txt',  'r') as file1: 
    for row in file1.readlines(): 
        row.startswith('s')
